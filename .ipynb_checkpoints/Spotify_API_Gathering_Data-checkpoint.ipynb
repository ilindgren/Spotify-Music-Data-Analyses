# %% [markdown]
# # How to Gather Personal Playlist Data from Spotify API

# %% [markdown]
# Spotify API: https://developer.spotify.com/documentation/web-api/reference/tracks/

# %% [markdown]
# Now that we have our Spotify credentials...
# I used this code from https://github.com/sejaldua/lyrical-sentiment-analysis/blob/master/.ipynb_checkpoints/public_code-checkpoint.ipynb

# %%
#!pip install spotipy
import spotipy as sp
import numpy
from spotipy.oauth2 import SpotifyClientCredentials


username='izzy730'
client_id = '64cb58457d8a44e98b93b1761b82be6d'
client_secret = '03500ec43fef4db6933523d4d5b43304'
redirecturi='izzys-personal-playlist://callback'
thescope='playlist-read-private'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
plists = {}

def get_features_for_playlist(uri):
    playlist_id = uri.split(':')[2]
    results = sp.user_playlist(username, playlist_id)
    
    #print(json.dumps(results, indent=4))               # uncomment this if you want to visualize the JSON structure
    
    playlist_name = results['name']
    plists[playlist_name] = {}
    plists[playlist_name]['name'] = []
    plists[playlist_name]['track uri'] = []
    plists[playlist_name]['acousticness'] = []
    plists[playlist_name]['danceability'] = []
    plists[playlist_name]['energy'] = []
    plists[playlist_name]['instrumentalness'] = []
    plists[playlist_name]['liveness'] = []
    plists[playlist_name]['loudness'] = []
    plists[playlist_name]['speechiness'] = []
    plists[playlist_name]['tempo'] = []
    plists[playlist_name]['valence'] = []
    plists[playlist_name]['popularity'] = []

    for track in results['tracks']['items']:
        
        # print(json.dumps(track, indent=4))              # DEBUG STATEMENT
        name = track['track']['name']
        print(name)
        track_uri = track['track']['uri']
        plists[playlist_name]['name'].append(name)
        plists[playlist_name]['track uri'].append(track_uri)

        features = sp.audio_features(track_uri)
        plists[playlist_name]['acousticness'].append(features[0]['acousticness'])
        plists[playlist_name]['danceability'].append(features[0]['danceability'])
        plists[playlist_name]['energy'].append(features[0]['energy'])
        plists[playlist_name]['instrumentalness'].append(features[0]['instrumentalness'])
        plists[playlist_name]['liveness'].append(features[0]['liveness'])
        plists[playlist_name]['loudness'].append(features[0]['loudness'])
        plists[playlist_name]['speechiness'].append(features[0]['speechiness'])
        plists[playlist_name]['tempo'].append(features[0]['tempo'])
        plists[playlist_name]['valence'].append(features[0]['valence'])
    
uris = ['spotify:playlist:37i9dQZF1DXaMu9xyX1HzK', 'spotify:playlist:37i9dQZF1EtkXRUBe6Gwsv', 'spotify:playlist:37i9dQZF1EjsoXeGR7MZ0Q']
for uri in uris:
        get_features_for_playlist(uri)

print(plists)
# Out:
# I Like Me Better
# Beautiful People (feat. Khalid)
# Without Me
# Sucker
# thank u, next
# Youngblood
# Beautiful (feat. Camila Cabello)
# Dancing With A Stranger (with Normani)
# Happier
# 7 rings
# Someone You Loved
# Let Me Go (with Alesso, Florida Georgia Line & watt)
# The Middle
# It's You
# Tequila
# Trampoline (with ZAYN)
# Señorita
# The Bones
# You Need To Calm Down
# Circles
# Little Do You Know
# Girls Like You (feat. Cardi B)
# Say You Won't Let Go
# Blank Space
# Scars To Your Beautiful
# One Thing Right
# Riptide
# Sorry Not Sorry
# Delicate
# Sweet but Psycho
# Treat You Better
# Young Dumb & Broke
# Meant to Be (feat. Florida Georgia Line)
# when the party's over
# YOUTH
# Classic
# Sit Still, Look Pretty
# Please Don't Go
# no tears left to cry
# Me And My Broken Heart
# High Hopes
# Starving
# Story of My Life
# Good as Hell
# Never Be the Same
# Don't Call Me Up
# 1950
# Better Now
# Best Part (feat. Daniel Caesar)
# There's Nothing Holdin' Me Back
# Mine
# Mine
# Shout Out to My Ex
# Drag Me Down
# Bad At Love
# Love Lies (with Normani)
# FRIENDS
# Sunflower - Spider-Man: Into the Spider-Verse
# Stay
# No Guidance (feat. Drake)
# Closer
# Lucid Dreams
# I'll Be There
# Slow Hands
# Tonight Tonight
# Shallow
# PILLOWTALK
# What Makes You Beautiful
# My My My!
# Attention
# Baby
# Truth Hurts
# I Fall Apart
# Payphone
# I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"
# bad guy
# Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)
# Never Forget You
# Lost Boy
# Fight Song
# Issues
# Heart Attack
# Stitches
# Back To December
# Old Town Road - Remix
# Dancing On My Own
# Let You Down
# Love Yourself
# In the Name of Love
# Body
# All Too Well
# What the Hell
# Location
# Counting Stars
# Hurts So Good
# 11 Minutes (with Halsey feat. Travis Barker)
# There for You
# Always Remember Us This Way
# New Rules
# These Days (feat. Jess Glynne, Macklemore & Dan Caplen)
# MIDDLE CHILD
# Vertigo
# Sandstorm (feat. JID)
# Hard Place
# Groceries
# Talk
# bury a friend
# Almost (Sweet Music)
# Chateau
# Someday - triple j Like A Version
# 151 Rum
# Dreams - 2004 Remaster
# Life Itself
# Changing of the Seasons
# Weekend Friend
# Let Me Down Easy
# Truth Hurts
# BROWN SKIN GIRL
# Someday
# Everywhere - 2017 Remaster
# Nice For What
# Pink + White
# Way Down
# How Do You Sleep?
# In the Air
# Curls
# The King of Wishful Thinking
# Off Deez (with J. Cole)
# XO
# So Close
# Treat You Better
# Leave Me Lonely
# Vossi Bop
# Circles
# Faces
# retrying ...3secs
# Pussy Is God
# Money In The Grave (Drake ft. Rick Ross)
# Feel Good Inc.
# Midsummer Madness
# bellyache
# The Other Side Of Paradise
# Best Part (feat. H.E.R.)
# Give Me One Reason
# bad guy
# Going Bad (feat. Drake)
# The Man
# You Make My Dreams
# Wow.
# Hasta Luego - Bonus
# I Miss You
# Rum Rage
# Good In You - MagnusTheMagnus & Carli 2 Step Rewind Edit
# Sleep
# Someone That You Love
# Nobody's Home
# i'm so tired...
# Hold Up
# Mob Ties
# Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)
# I Don't Care (with Justin Bieber)
# Cool
# The Need to Know (feat. SZA)
# Ain't No Man
# Quick Musical Doodles
# Charlie
# Don't Hurt Yourself (feat. Jack White)
# How To Fly
# Honey
# Say Say Say - Remastered 2015
# Gloria
# Do It Like You
# Starlight
# One Last Song
# KOD
# Gypsy
# If I Can't Have You
# You Only Live Once
# Lo/Hi
# Coming Home (feat. Ms. Lauryn Hill)
# Omertà
# Sorry
# The Chain - 2004 Remaster
# Everything Is Alright
# Spaceman
# Season 2 Episode 3
# Joan of Arc.
# The Diving Bell
# Dancing With A Stranger (with Normani)
# Youth
# Say My Name
# All Of Us
# Pretty Little Fears (feat. J. Cole)
# LIFE
# Olalla
# Oh Sherrie
# This Life
# Photosynthesis
# REEL IT IN
# Paris in the Rain
# Latch
# Let Me Down Easy
# Nice For What
# Paris in the Rain
# Slow (feat. Noah Cyrus) - CID Remix
# Kick On
# Love Lies (with Normani)
# Different Skies
# Life Itself
# Used to Be in Love
# TEMPTATION
# Chateau
# Better Not (feat. Wafia)
# In My Feelings
# The Man
# Satisfied (feat. MAX)
# Rum Rage
# Back Down South
# Big Fish
# Agnes
# Liquor Locker
# Pink + White
# Alone (Feat. Big Sean & Stefflon Don)
# Morning Light
# Need You
# One Last Song
# Tell Me You Love Me
# How To Fly
# It's Strange (feat. K.Flay)
# Nonstop
# APESHIT
# Angela
# Chasing Fire
# Nights
# ATM
# The Deepest Sighs, the Frankest Shadows
# Someday
# Flow
# Bootleg Rascal
# Lucky You (feat. Joyner Lucas)
# retrying ...3secs
# I Like It
# Lemon - Drake Remix
# Feel Good Inc.
# Youth
# Say My Name (feat. Zyra)
# Lethal Combination
# Crave You
# Come Down
# Hurt Somebody (With Julia Michaels)
# Hell & Back
# You Only Live Once
# Atomic Man
# 1985
# Chun-Li
# Good Nights (feat. Mascolo)
# Sun Models (feat. Madelyn Grant)
# Sensualidad
# Stranger Things
# Black Mambo
# Bulletproof
# Australia Street
# Janet
# Mine
# Terrified
# The Chain
# Diddy Bop (x Louis The Child)
# Supercut - El-P Remix
# Don't Feel Like Lovin'
# Sorry
# Confidence
# X
# Snow
# Get Lucky (triple j Like A Version)
# Moon River
# The Weekend - Funk Wav Remix
# Low Tide Love - Acoustic
# KOD
# Sun In Our Eyes
# Way to be Loved
# Happier
# Say Say Say - Remastered 2015
# The Ringer
# R U Mine?
# Calypso
# Changing Of The Seasons
# Keeping Score (feat. Paige IV)
# I Blame Myself
# No Role Modelz
# Human
# Arms
# Dante's Creek
# Hold On Tight
# 2
# Shaky Ground
# Liquorlip Loaded Gun
# Your Side Of The Bed
# Hoops
# True Feeling
# Hope (feat. Naomi Wild)
# Pretty Little Fears (feat. J. Cole)
# I'm Not The Only One
# {'Best of the Decade For You': {'name': ['I Like Me Better', 'Beautiful People (feat. Khalid)', 'Without Me', 'Sucker', 'thank u, next', 'Youngblood', 'Beautiful (feat. Camila Cabello)', 'Dancing With A Stranger (with Normani)', 'Happier', '7 rings', 'Someone You Loved', 'Let Me Go (with Alesso, Florida Georgia Line & watt)', 'The Middle', "It's You", 'Tequila', 'Trampoline (with ZAYN)', 'Señorita', 'The Bones', 'You Need To Calm Down', 'Circles', 'Little Do You Know', 'Girls Like You (feat. Cardi B)', "Say You Won't Let Go", 'Blank Space', 'Scars To Your Beautiful', 'One Thing Right', 'Riptide', 'Sorry Not Sorry', 'Delicate', 'Sweet but Psycho', 'Treat You Better', 'Young Dumb & Broke', 'Meant to Be (feat. Florida Georgia Line)', "when the party's over", 'YOUTH', 'Classic', 'Sit Still, Look Pretty', "Please Don't Go", 'no tears left to cry', 'Me And My Broken Heart', 'High Hopes', 'Starving', 'Story of My Life', 'Good as Hell', 'Never Be the Same', "Don't Call Me Up", '1950', 'Better Now', 'Best Part (feat. Daniel Caesar)', "There's Nothing Holdin' Me Back", 'Mine', 'Mine', 'Shout Out to My Ex', 'Drag Me Down', 'Bad At Love', 'Love Lies (with Normani)', 'FRIENDS', 'Sunflower - Spider-Man: Into the Spider-Verse', 'Stay', 'No Guidance (feat. Drake)', 'Closer', 'Lucid Dreams', "I'll Be There", 'Slow Hands', 'Tonight Tonight', 'Shallow', 'PILLOWTALK', 'What Makes You Beautiful', 'My My My!', 'Attention', 'Baby', 'Truth Hurts', 'I Fall Apart', 'Payphone', 'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"', 'bad guy', 'Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)', 'Never Forget You', 'Lost Boy', 'Fight Song', 'Issues', 'Heart Attack', 'Stitches', 'Back To December', 'Old Town Road - Remix', 'Dancing On My Own', 'Let You Down', 'Love Yourself', 'In the Name of Love', 'Body', 'All Too Well', 'What the Hell', 'Location', 'Counting Stars', 'Hurts So Good', '11 Minutes (with Halsey feat. Travis Barker)', 'There for You', 'Always Remember Us This Way', 'New Rules', 'These Days (feat. Jess Glynne, Macklemore & Dan Caplen)'], 'track uri': ['spotify:track:2P91MQbaiQOfbiz9VqhqKQ', 'spotify:track:70eFcWOvlMObDhURTqT4Fv', 'spotify:track:5p7ujcrUXASCNwRaWNHR1C', 'spotify:track:22vgEDb5hykfaTwLuskFGD', 'spotify:track:3e9HZxeyfWwjeyPAMmWSSQ', 'spotify:track:2iUXsYOEPhVqEBwsqP70rE', 'spotify:track:4VUwkH455At9kENOfzTqmF', 'spotify:track:6Qs4SXO9dwPj5GKvVOv8Ki', 'spotify:track:2dpaYNEQHiRxtZbfNsse99', 'spotify:track:6ocbgoVGwYJhOv1GgI9NsF', 'spotify:track:7qEHsqek33rTcFNT9PFqLf', 'spotify:track:5Gu0PDLN4YJeW75PpBSg9p', 'spotify:track:09IStsImFySgyp0pIQdqAc', 'spotify:track:6moU77g9RQyMzHNuKEaQKq', 'spotify:track:7Il2yWQmsqKgSkLQvHTPUI', 'spotify:track:1iQDltZqI7BXnHrFy4Qo1k', 'spotify:track:6v3KW9xbzN5yKLt9YKDYA2', 'spotify:track:3npzogdOEiVsieXmmhBepL', 'spotify:track:6RRNNciQGZEXnqk8SQ9yv5', 'spotify:track:21jGcNKet2qwijlDFuPiPb', 'spotify:track:1almCHdsfikRPfVB9VrEdT', 'spotify:track:6V1bu6o1Yo5ZXnsCJU8Ovk', 'spotify:track:5uCax9HTNlzGybIStD3vDh', 'spotify:track:2ls70nUDfjzm1lSRDuKxmw', 'spotify:track:0prNGof3XqfTvNDxHonvdK', 'spotify:track:4hPpVbbakQNv8YTHYaOJP4', 'spotify:track:7yq4Qj7cqayVTp3FF9CWbm', 'spotify:track:7gvd8xj4QgPqbQSsn5pV7d', 'spotify:track:6NFyWDv5CjfwuzoCkw47Xf', 'spotify:track:25sgk305KZfyuqVBQIahim', 'spotify:track:3QGsuHI8jO1Rx4JWLUh9jd', 'spotify:track:5Z3GHaZ6ec9bsiI5BenrbY', 'spotify:track:7iDa6hUg2VgEL1o1HjmfBn', 'spotify:track:43zdsphuZLzwA9k4DJhU0I', 'spotify:track:1cOyWWUr3oXJIxY0AjJEx9', 'spotify:track:6FE2iI43OZnszFLuLtvvmg', 'spotify:track:0EGuSSpuu9wmHCtvb4PdLO', 'spotify:track:3cNjgVBKTJ1SvKhunrCdVy', 'spotify:track:2qT1uLXPVPzGgFOx4jtEuo', 'spotify:track:1oew3nFNY3vMacJAsvry0S', 'spotify:track:1rqqCSm0Qe4I9rUvWncaom', 'spotify:track:6DG2g1UhROp5pnM8fx7zH2', 'spotify:track:4nVBt6MZDDP6tRVdQTgxJg', 'spotify:track:3Yh9lZcWyKrK9GjbhuS0hR', 'spotify:track:4eWQlBRaTjPPUlzacqEeoQ', 'spotify:track:5WHTFyqSii0lmT9R21abT8', 'spotify:tra ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# manually inspect all of the values to determine whether the median or mean is a better metric to plot
for playlist in plists:
    print("––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––")
    print(playlist)
    for feature in plists[playlist]:
        if feature != 'name' and feature != 'track uri':
            print(feature.upper(), "| median:", np.median(plists[playlist][feature]), "| mean:", np.mean(plists[playlist][feature]))
    

labels = ['acousticness', 'danceability', 'energy', 'valence', 'instrumentalness', 'tempo', 'speechiness']
num_vars = len(labels)

# Split the circle into even parts and save the angles so we know where to put each axis.
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]

# ax = plt.subplot(polar=True)
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Helper function to plot each playlist on the radar chart.
def add_to_radar(playlist, color):
    values = [np.median(plists[playlist]['acousticness']), np.median(plists[playlist]['danceability']), np.median(plists[playlist]['energy']), 
              np.median(plists[playlist]['valence']), np.mean(plists[playlist]['instrumentalness']), np.median(plists[playlist]['tempo']), 
              np.median(plists[playlist]['speechiness'])]
    # tempo values typically range from 50-220, so I divided by 220 to get a number between 0 and 1
    values[-2] = values[-2]/220
    # speechiness values values are highly concentrated between 0 and 0.25-ish, so I multiplied by 4. Adjust this if needed
    values[-1] = values[-1]*4
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=1, label=playlist)
    ax.fill(angles, values, color=color, alpha=0.25)

# # Add each additional playlist to the chart.
add_to_radar('Best of the Decade For You', 'red')
add_to_radar('Your Top Songs 2019', 'green')
add_to_radar('Your Top Songs 2018', 'blue')

# polar coordinates math stuff
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)

# Draw axis lines for each angle and label.
ax.set_thetagrids(np.degrees(angles), labels)

# Go through labels and adjust alignment based on where it is in the circle.
for label, angle in zip(ax.get_xticklabels(), angles):
    if angle in (0, np.pi):
        label.set_horizontalalignment('center')
    elif 0 < angle < np.pi:
        label.set_horizontalalignment('left')
    else:
        label.set_horizontalalignment('right')
    
# Set position of y-labels (0-100) to be in the middle of the first two axes.
ax.set_ylim(0, 1)
ax.set_rlabel_position(180 / num_vars)

# Add some custom styling.
ax.tick_params(colors='#222222')         # color of tick labels
ax.tick_params(axis='y', labelsize=8)    # y-axis labels
ax.grid(color='#AAAAAA')                 # color of circular gridlines
ax.spines['polar'].set_color('#222222')  # color of outermost gridline (spine)
ax.set_facecolor('#FAFAFA')              # background color inside the circle itself

#Lastly, give the chart a title and a legend
ax.set_title('Playlist Comparison', y=1.08)
ax.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

fig.savefig('playlist_comp.png')
# Out:
# ––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
# Best of the Decade For You
# ACOUSTICNESS | median: 0.12 | mean: 0.22206809999999996
# DANCEABILITY | median: 0.6775 | mean: 0.6580399999999998
# ENERGY | median: 0.66 | mean: 0.631645
# INSTRUMENTALNESS | median: 0.0 | mean: 0.0014365272000000004
# LIVENESS | median: 0.121 | mean: 0.157137
# LOUDNESS | median: -5.6080000000000005 | mean: -5.8397299999999985
# SPEECHINESS | median: 0.055999999999999994 | mean: 0.089245
# TEMPO | median: 113.2205 | mean: 114.98683000000001
# VALENCE | median: 0.4795 | mean: 0.485711
# POPULARITY | median: nan | mean: nan
# ––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
# Your Top Songs 2019
# ACOUSTICNESS | median: 0.167 | mean: 0.255446558
# DANCEABILITY | median: 0.674 | mean: 0.65664
# ENERGY | median: 0.6425000000000001 | mean: 0.62054
# INSTRUMENTALNESS | median: 1.3205e-05 | mean: 0.05395994830000001
# LIVENESS | median: 0.118 | mean: 0.17697
# LOUDNESS | median: -6.9055 | mean: -7.38054
# SPEECHINESS | median: 0.07594999999999999 | mean: 0.116827
# TEMPO | median: 120.3365 | mean: 122.86746
# VALENCE | median: 0.5345 | mean: 0.526382
# POPULARITY | median: nan | mean: nan
# ––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
# Your Top Songs 2018
# ACOUSTICNESS | median: 0.14350000000000002 | mean: 0.23611646100000006
# DANCEABILITY | median: 0.6755 | mean: 0.65753
# ENERGY | median: 0.6285000000000001 | mean: 0.62101
# INSTRUMENTALNESS | median: 3.39e-05 | mean: 0.0472591101
# LIVENESS | median: 0.114 | mean: 0.18541300000000002
# LOUDNESS | median: -6.765499999999999 | mean: -6.94919
# SPEECHINESS | median: 0.0559 | mean: 0.10638099999999998
# TEMPO | median: 120.0065 | mean: 121.78524000000002
# VALENCE | median: 0.4985 | mean: 0.5069070000000001
# POPULARITY | median: nan | mean: nan

# %% [markdown]
# ## Data Formatting and Cleaning

# %%
izzy_df = pd.DataFrame(plists)
izzy_df.head(10)

# %%
bestofdecade_df = izzy_df['Best of the Decade For You']
izzy2019_df = izzy_df['Your Top Songs 2019']
izzy2018_df = izzy_df['Your Top Songs 2018']

# %%
bestofdecade_df = pd.DataFrame(bestofdecade_df)
bestofdecade_df

# %%
bestofdecade_df.reset_index(level=0, inplace=True)
bestofdecade_df

# %%
df2 = pd.DataFrame(bestofdecade_df)
print (df2)

# %%
df3 = pd.DataFrame(df2['Best of the Decade For You'].values.tolist())
print (df3)

# %%
bestofdecade_df = df3.T
bestofdecade_df.head()

# %%
bestofdecade_df.rename(columns = {0:'acousticness', 1:'danceability', 2:'energy', 3:'instrumentalness',
                                 4:'liveness', 5:'loudness', 6:'track', 7:'speechiness', 8:'tempo', 9:'track_uri',
                                 10:'valence'}, inplace=True)
print(bestofdecade_df.columns)

# %%
bestofdecade_df

# %%
izzy2019_df = izzy_df['Your Top Songs 2019']
izzy2019_df = pd.DataFrame(izzy2019_df)
izzy2019_df

# %%
izzy2019_df.reset_index(level=0, inplace=True)
izzy2019_df

# %%
df2 = pd.DataFrame(izzy2019_df)
print (df2)
df3 = pd.DataFrame(df2['Your Top Songs 2019'].values.tolist())
print (df3)

# %%
izzy2019_df = df3.T
izzy2019_df.head()

# %%
izzy2019_df.rename(columns = {0:'acousticness', 1:'danceability', 2:'energy', 3:'instrumentalness',
                                 4:'liveness', 5:'loudness', 6:'track', 7:'speechiness', 8:'tempo', 9:'track_uri',
                                 10:'valence'}, inplace=True)
print(izzy2019_df.columns)
izzy2019_df.head()

# %%
izzy2018_df = izzy_df['Your Top Songs 2018']
izzy2018_df = pd.DataFrame(izzy2018_df)
izzy2018_df

# %%
izzy2018_df.reset_index(level=0, inplace=True)
izzy2018_df

# %%
df2 = pd.DataFrame(izzy2018_df)
print (df2)
df3 = pd.DataFrame(df2['Your Top Songs 2018'].values.tolist())
print (df3)

# %%
izzy2018_df = df3.T
izzy2018_df.head()

# %%
izzy2018_df.rename(columns = {0:'acousticness', 1:'danceability', 2:'energy', 3:'instrumentalness',
                                 4:'liveness', 5:'loudness', 6:'track', 7:'speechiness', 8:'tempo', 9:'track_uri',
                                 10:'valence'}, inplace=True)
print(izzy2018_df.columns)
izzy2018_df.head()
